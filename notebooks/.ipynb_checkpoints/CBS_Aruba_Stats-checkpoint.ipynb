# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import openpyxl

# Import Class
from pathlib import Path

# %%
# Set Path to current working directoryu
cwd = Path.cwd()

# Set filesystem paths
ROOT = cwd.parent if cwd.name == "notebooks" else cwd

# %%
# Test ROOT
ROOT
# Out:
# PosixPath('/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks')

# %%
# Create DATA_RAW
DATA_RAW = ROOT / "data" / "raw"

# %%
# Test DATA_RAW
DATA_RAW
# Out:
# PosixPath('/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/data/raw')

# %%
# Create DATA_PROCESSED
DATA_PROCESSED = ROOT / "data" / "processed"

# %%
# Create FIGURES
FIGURES = ROOT / "figures"

# %%
# Test all paths
ROOT, DATA_PROCESSED, FIGURES
# Out:
# (PosixPath('/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks'),
#  PosixPath('/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/data/processed'),
#  PosixPath('/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/figures'))

# %%
# Set scope in years of available data
YEAR_MIN = 2015

# %%
YEAR_MAX = 2023

# %%
# Test variables
YEAR_MIN, YEAR_MAX
# Out:
# (2015, 2023)

# %%
# Verify all paths
print("ROOT:", ROOT)
print("RAW DATA:", DATA_RAW)
print("PROCESSED DATA:", DATA_PROCESSED)
print("FIGURES:", FIGURES)
# Out:
# ROOT: /home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks
# RAW DATA: /home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/data/raw
# PROCESSED DATA: /home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/data/processed
# FIGURES: /home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/figures

# %%
RAW_DEMOGRAPHIC_ASPECTS_FILE = DATA_RAW / "Demographic-aspects-2023.xlsx"

# %%
# Set variable for wide format
df_wide = pd.read_excel(RAW_DEMOGRAPHIC_ASPECTS_FILE, header=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Set variable for wide format
# ----> 2 df_wide = pd.read_excel(RAW_DEMOGRAPHIC_ASPECTS_FILE, header=1)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/excel/_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ggirelli/Documents/DataAnalysis/Scripts/Python/Notebooks/data/raw/Demographic-aspects-2023.xlsx'

# %%
# Create "if statement" to test for errors
if not RAW_DEMOGRAPHIC_ASPECTS_FILE.exists():
    raise FileNotFoundError

# %%
# 1. Filter the data into our two groups
males = df[df["Key Demographic aspects"] == "Males"]
females = df[df["Key Demographic aspects"] == "Females"]

# 2. Calculate the yearly change (slicing 2015 to 2023)
# We use .diff(axis=1) to subtract each year from the previous one
yearly_change_males = males.loc[:, 2015:2023].diff(axis=1)
yearly_change_females = females.loc[:, 2015:2023].diff(axis=1)

# 3. Combine them into one comparison table
comparison_df = pd.concat([yearly_change_males, yearly_change_females], keys=["Males", "Females"])

# 4. Clean up: drop the extra index level and fill the 2015 NaNs with 0
comparison_df = comparison_df.droplevel(1).fillna(0)

# 5 Create the plot
comparison_df.T.plot(kind="line", marker="o", grid=True, figsize=(12, 7), title="Impact of Pandemic on Population Change")

# 6. Add specific y-axis ticks (from -800 to 500, every 100)
plt.yticks(np.arange(-800, 501, 100))

# 7. Add the labels
plt.ylabel("Annual Growth / Decline (Absolute)")
plt.xlabel("Year")

# 8. Add a horizontal line at 0 to highlight the "Recovery" threshold
plt.axhline(0, color="black", linestyle="--", linewidth=1)

plt.savefig("Demographic_Changes_Aruba-2015-2023")
plt.show()
