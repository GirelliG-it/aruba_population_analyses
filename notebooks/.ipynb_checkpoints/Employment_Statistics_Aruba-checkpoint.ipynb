# %%
# Import libraries
import pandas as pd

# Load dataframe
df = pd.read_excel("/home/ggirelli/Documents/DataAnalysis/Datasets/Official_Open-Datasets_Aruba_CBS/Table-7.3-Number-of-registered-jobs-with-SVB-by-economic-sector-by-gender-2015-2024.xlsx", header=None)

# Inspect
df.head()
df.info()

# Create colimns
sex_row = df.iloc[1]
year_row = df.iloc[2]


# Use forward fill to fill in NaNs
sex_row =  sex_row.ffill()


year_row_cleaned = pd.to_numeric(year_row, errors="coerce")

sex_row = df.iloc[1, 2:].ffill()
year_row = pd.to_numeric(df.iloc[2, 2:], errors="coerce")

# Validity mask / this keeps only columns where a year exists
valid_cols = year_row.notna()

# Apply validity mask to both cols
sex_row =  sex_row[valid_cols]
year_row = year_row[valid_cols]

# Combine using zip()
cleaned_columns = list(zip(year_row.astype(int), sex_row))

print(cleaned_columns)

# Inspect column with sector names
data = df.iloc[3:, :].copy()

data = data.loc[:, valid_cols.index[valid_cols]]
print(data)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     str
#  1   1       22 non-null     str
#  2   2       23 non-null     object
#  3   3       22 non-null     float64
#  4   4       22 non-null     float64
#  5   5       22 non-null     float64
#  6   6       22 non-null     float64
#  7   7       22 non-null     float64
#  8   8       22 non-null     float64
#  9   9       22 non-null     float64
#  10  10      22 non-null     float64
#  11  11      22 non-null     float64
#  12  12      0 non-null      float64
#  13  13      23 non-null     object
#  14  14      22 non-null     float64
#  15  15      22 non-null     float64
#  16  16      22 non-null     float64
#  17  17      22 non-null     float64
#  18  18      22 non-null     float64
#  19  19      22 non-null     float64
#  20  20      22 non-null     float64
# ...
