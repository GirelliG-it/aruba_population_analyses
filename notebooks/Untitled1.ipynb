# %%
import pandas as pd

import pandas as pd

# 1. Load the file into a variable (df)
file_path = "/home/ggirelli/Downloads/Date_time_excercise.xlsx"
df = pd.read_excel(file_path)

# 2. Now convert the specific column inside that variable
df["Transaction_time"] = pd.to_datetime(df["Transaction_time"], errors='coerce')

# 3. Now extract the hour
df["Hour"] = df["Transaction_time"].dt.hour

# View the result
print(df.head())
# Out:
#    Employee_Id Employee _Name Transaction_time  Hour
# 0         2222           John              NaT   NaN
# 1         4690            Sam              NaT   NaN
# 2         4479          Julie              NaT   NaN
# 3         2738         Sandra              NaT   NaN
# 4         5844       Samantha              NaT   NaN
