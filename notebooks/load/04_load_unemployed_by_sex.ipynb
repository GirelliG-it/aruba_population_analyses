# %% [markdown]
# # Load: Unemployed and inactive individuals by sex, 2015–2024
#
# **Source file:** `Table-6.8-Number-of-unemployed-and-number-of-inactive-individuals-by-sex-2015-2024.xlsx`
# **Source:** Department of Labor and Research, Central Bank of Aruba, CBS
#
# **Pipeline:**
# 1. Load raw Excel → clean headers → tidy long format
# 2. Save to `data/processed/unemployed_by_sex.parquet`
# 3. Register as DuckDB view `unemployed_by_sex`
#
# **Notes:**
# - 2022 has two observations: June and November surveys
# - Values are weighted float estimates, not raw counts
# - `period` column: "annual", "Jun", or "Nov"

# %%
import pandas as pd
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.parent if Path.cwd().name == "load" else Path.cwd()))
